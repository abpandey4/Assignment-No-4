# %% [markdown]
# # Assignment No 4

# %% [markdown]
# ## Machine Learning 1

# %% [markdown]
#  Question 1 : What are the three stages of build the hypothesis or model in Machiner Learning.
#
#
#  Answer1 : The three stages of building the hypotheses or model in machine learning:
#
#            Model Buliding
#
#            Model Testing
#
#            Applying the model.

# %% [markdown]
# Question 2: What is the standard approach to supervised Learning.
#
#  Answer2 : The standard approach to supervised learning is to split the set of example into the training set              and the test.

# %% [markdown]
# Question3 : What is Training set and Test set.
#
# Answer3 :
#
#        Trainig set - A set of data is used to discover the potentially predictive relationship known as trainig        set.
#
#        Test set -  Test set is used to test the accuracy of the hypotheses generated by the learner

# %% [markdown]
# Question4 : What is the general principle of an ensemble method and what is bagging and boosting in ensemble method?
#
# Answer4 : The general principle of an ensemble method is to combine the predictions of several models built with a given learning algorithm in order to improve robustness over a single model.
#
# Bagging - Bagging is a method in ensemble for improving unstable estimation or classification schemes.
#
# Boosting - Boosting method are used sequentially to reduce the bias of the combined model.

# %% [markdown]
# Question5 : How can you avoid Overfitting ?
#
# Answer5 : By using a lot of data overfitting can be avoided
